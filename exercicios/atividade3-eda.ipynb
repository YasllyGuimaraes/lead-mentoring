# %% [markdown]
# # 1
# Escolha um conjunto de dados e realize uma análise exploratória de dados (EDA).
#
# Lembre-se de:
#
# - verificar os dados
# - realizar a limpeza de dados nulos
# - utilizar plots para entender os dados
# - tentar tirar "pequenas conclusões" dos dados

# %% [markdown]
# Algumas fontes de conjunto de dados:
#
# - [UCI Repository](https://archive.ics.uci.edu/ml/index.php)
# - [Scikit-learn](https://scikit-learn.org/stable/datasets/toy_dataset.html)
# - [Seaborn](https://seaborn.pydata.org/generated/seaborn.load_dataset.html)
# - [Kaggle](https://www.kaggle.com/datasets)

# %% [markdown]
# Caso deseje, utilize o conjunto de dados [Dataset: NetFlix Shows](https://www.kaggle.com/datasets/infamouscoder/dataset-netflix-shows?select=netflix_titles.csv).
#
# É possível realizar o download do arquivo no [Kaggle](https://www.kaggle.com/datasets/infamouscoder/dataset-netflix-shows?select=netflix_titles.csv) ou utilizar o arquivo disponível em: [netflix_titles.csv](../notebooks/netflix_titles.csv)

# %% [markdown]
# Outros conjuntos de dados interessantes são:
#
# - [Iris](https://www.kaggle.com/datasets/uciml/iris)
# - [Titanic](https://www.kaggle.com/competitions/titanic/data?select=train.csv)
# - [Palmer Penguins](https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data)
# - [Students Performance in Exams](https://www.kaggle.com/datasets/spscientist/students-performance-in-exams)
# - [Brazilian E-Commerce Public Dataset by Olist](https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce)

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
students_df = pd.read_csv('Student Mental health.csv')
students_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
dados_df = students_df.copy()
dados_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
# Para saber o título das colunas:
list(dados_df.columns)
# Out:
# ['Timestamp',
#  'Choose your gender',
#  'Age',
#  'What is your course?',
#  'Your current year of Study',
#  'What is your CGPA?',
#  'Marital status',
#  'Do you have Depression?',
#  'Do you have Anxiety?',
#  'Do you have Panic attack?',
#  'Did you seek any specialist for a treatment?']

# %%
print(f"O conjunto de dados possui {len(dados_df)} amostras e {len(dados_df.columns)} colunas")
# Out:
# O conjunto de dados possui 101 amostras e 11 colunas

# %%
dados_df.isna().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %% [markdown]
# Há apenas um dado faltante em na coluna Age.

# %%
#Realizando limpeza de dados nulos : substituindo por No_data.
dados_df['Age'].fillna('No_data',inplace=True)
dados_df.head(44)
# Out:
#          Timestamp Choose your gender      Age     What is your course?  \
# 0   8/7/2020 12:02             Female     18.0              Engineering
# 1   8/7/2020 12:04               Male     21.0        Islamic education
# 2   8/7/2020 12:05               Male     19.0                      BIT
# 3   8/7/2020 12:06             Female     22.0                     Laws
# 4   8/7/2020 12:13               Male     23.0             Mathemathics
# 5   8/7/2020 12:31               Male     19.0              Engineering
# 6   8/7/2020 12:32             Female     23.0         Pendidikan islam
# 7   8/7/2020 12:33             Female     18.0                      BCS
# 8   8/7/2020 12:35             Female     19.0          Human Resources
# 9   8/7/2020 12:39               Male     18.0                    Irkhs
# 10  8/7/2020 12:39             Female     20.0               Psychology
# 11  8/7/2020 12:39             Female     24.0              Engineering
# ...

# %%
#Agora não temos mais nenhum valor faltante
dados_df.dropna(inplace=True)

# %%
len(dados_df)
# Out:
# 101

# %% [markdown]
# Foi retirada a linha 43 que possuia o valor que não possuia dados.Após essa retirada o conjunto ficou com 100 amostras.

# %%
dados_df.head(44)
# Out:
#          Timestamp Choose your gender      Age     What is your course?  \
# 0   8/7/2020 12:02             Female     18.0              Engineering
# 1   8/7/2020 12:04               Male     21.0        Islamic education
# 2   8/7/2020 12:05               Male     19.0                      BIT
# 3   8/7/2020 12:06             Female     22.0                     Laws
# 4   8/7/2020 12:13               Male     23.0             Mathemathics
# 5   8/7/2020 12:31               Male     19.0              Engineering
# 6   8/7/2020 12:32             Female     23.0         Pendidikan islam
# 7   8/7/2020 12:33             Female     18.0                      BCS
# 8   8/7/2020 12:35             Female     19.0          Human Resources
# 9   8/7/2020 12:39               Male     18.0                    Irkhs
# 10  8/7/2020 12:39             Female     20.0               Psychology
# 11  8/7/2020 12:39             Female     24.0              Engineering
# ...

# %% [markdown]
# Modificando os valores da coluna [Your current year of Study] pois existiam 'year' escrito de diferentes formas.

# %%
dados_df['Your current year of Study'].replace('Year 1', 'year 1', inplace=True)
dados_df['Your current year of Study'].replace('Year 2', 'year 2', inplace=True)
dados_df['Your current year of Study'].replace('Year 3', 'year 3', inplace=True)
dados_df['Your current year of Study'].replace('Year 4', 'year 4', inplace=True)
dados_df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
dados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           101 non-null    object
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
sb.countplot(x='Choose your gender',data=dados_df)
# Out:
# <AxesSubplot:xlabel='Choose your gender', ylabel='count'>

# %% [markdown]
# Com o gráfico acima podemos concluir que a maior parte dos estudantes que preencheram o formulário foram mulheres.

# %%
dados_df['Choose your gender'].value_counts()
# Out:
# Female    75
# Male      26
# Name: Choose your gender, dtype: int64

# %%
sb.displot(data=dados_df, x="Choose your gender", hue="Do you have Depression?", col="Do you have Depression?")

# %% [markdown]
# De acordo com esse gráfico acima que correlaciona o indice de depressão dos alunos com o gênero é possível concluir que a maioria dos alunos, tanto homens quanto mulheres, não se consideram com depressão. Em contrapartida, ainda existem alunos e em sua maioria mulheres que se consideram com depressão.

# %%
sb.histplot(data=dados_df,x='Your current year of Study')
# Out:
# <AxesSubplot:xlabel='Your current year of Study', ylabel='Count'>

# %% [markdown]
# A maioria das pessoas que reponderam a pesquisa estão no primeiro ano.

# %%
#Colocando a coluna Timestamp em formato de data:
dados_df['Timestamp'] = pd.to_datetime(dados_df['Timestamp'])
dados_df.head()
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 0 2020-08-07 12:02:00             Female  18.0          Engineering
# 1 2020-08-07 12:04:00               Male  21.0    Islamic education
# 2 2020-08-07 12:05:00               Male  19.0                  BIT
# 3 2020-08-07 12:06:00             Female  22.0                 Laws
# 4 2020-08-07 12:13:00               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
# Separando as horas da data em novas colunas:
dados_df['Hour added'] = dados_df['Timestamp'].dt.time
dados_df['Data added'] = dados_df['Timestamp'].dt.date
dados_df.head()
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 0 2020-08-07 12:02:00             Female  18.0          Engineering
# 1 2020-08-07 12:04:00               Male  21.0    Islamic education
# 2 2020-08-07 12:05:00               Male  19.0                  BIT
# 3 2020-08-07 12:06:00             Female  22.0                 Laws
# 4 2020-08-07 12:13:00               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
ax = sb.histplot(data=dados_df,y='What is your course?')
ax.figure.set_size_inches(12, 12)

# %% [markdown]
# A maioria dos estudantes estão cursando BCS e Engenharia.

# %%
ax = sb.stripplot(x='Do you have Depression?', y='What is your course?', data=dados_df, hue='Do you have Depression?', split=True)
ax.figure.set_size_inches(5, 12)
# Out:
# c:\Users\Yaslly\miniconda3\envs\lead-mentoring\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# O índice de ataques de pânico se concentram mais nos cursos mais cursados: Engenharia, BIT e BCS.

# %%
sb.lineplot(
    data=dados_df, x="What is your CGPA?", y="Do you have Depression?", err_style="bars"
)


'''ax = sb.stripplot(x='Do you have Depression?', y='What is your CGPA?', data=dados_df, hue='Do you have Depression?', split=True)
ax.figure.set_size_inches(5, 12)'''
# Out:
# "ax = sb.stripplot(x='Do you have Depression?', y='What is your CGPA?', data=dados_df, hue='Do you have Depression?', split=True)\nax.figure.set_size_inches(5, 12)"

# %% [markdown]
# A maioria dos alunos que apresentam depressão são os alunos com as menores médias.
